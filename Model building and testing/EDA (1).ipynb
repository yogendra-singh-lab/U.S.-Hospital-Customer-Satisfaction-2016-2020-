# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df16= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2016.csv")
df17= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2017.csv")

# %%
df16["Patient Survey Star Rating"].value_counts()
# Out:
# Not Applicable    206701
# Not Available      15708
# 4                  14165
# 3                  14041
# 2                   8467
# 5                   3407
# 1                   1896
# Name: Patient Survey Star Rating, dtype: int64

# %%
df18= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2018.csv")
df19= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2019.csv")
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (14,17,19,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df20= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2020.csv")
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,14,17,19,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.set_option("display.max_columns",None)
print("shape of 2016 data set is {}:".format(df16.shape))
print("shape of 2017 data set is {}:".format(df17.shape))
print("shape of 2018 data set is {}:".format(df18.shape))
print("shape of 2019 data set is {}:".format(df19.shape))
print("shape of 2020 data set is {}:".format(df20.shape))
# Out:
# shape of 2016 data set is (264385, 43):
# shape of 2017 data set is (264660, 43):
# shape of 2018 data set is (239650, 43):
# shape of 2019 data set is (442401, 43):
# shape of 2020 data set is (442587, 43):

# %%
def columns_of_df(df):
    return df.head(3)
def info(df): # return the basic info of the dataset using df.info()
    return df.info()
def value_count(df):
    df_per = df16["Hospital overall rating"].value_counts().reset_index()
                                                                     
    df_per = df_per.sort_values(by = "index")
    return df_per

def per_cal(values,total):# % value for every  rating in each data set for 2016 -2018
    per_list = [None]*len(values)
    for i in range(len(values)):
        per_list[i] = (values[i]/total)*100
    return per_list

# %%
columns_of_df(df16)# 2016 data
# Out:
#    Facility ID                     Facility Name                 Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701     H_STAR_RATING
# 1  DOTHAN    AL     36301     HOUSTON    3347938701   H_CLEAN_HSP_A_P
# 2  DOTHAN    AL     36301     HOUSTON    3347938701  H_CLEAN_HSP_SN_P
#
#                                      HCAHPS Question  \
# 0                                Summary star rating
# 1  Patients who reported that their room and bath...
# 2  Patients who reported that their room and bath...
#
#                HCAHPS Answer Description Patient Survey Star Rating  \
# 0                    Summary star rating                          3
# ...

# %%
df16["HCAHPS Answer Description"]
# Out:
# 0                                       Summary star rating
# 1                                   Room was "always" clean
# 2                     Room was "sometimes" or "never" clean
# 3                                  Room was "usually" clean
# 4                           Cleanliness - linear mean score
#                                 ...
# 264380    "NO", patients would not recommend the hospita...
# 264381    "YES", patients would definitely recommend the...
# 264382               Recommend hospital - linear mean score
# 264383    "YES", patients would probably recommend the h...
# 264384                     Recommend hospital - star rating
# Name: HCAHPS Answer Description, Length: 264385, dtype: object

# %%
3500*55
# Out:
# 192500

# %%
columns_of_df(df17)# 2017 data
# Out:
#    Facility ID                     Facility Name                 Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701     H_STAR_RATING
# 1  DOTHAN    AL     36301     HOUSTON    3347938701   H_CLEAN_HSP_A_P
# 2  DOTHAN    AL     36301     HOUSTON    3347938701  H_CLEAN_HSP_SN_P
#
#                                      HCAHPS Question  \
# 0                                Summary star rating
# 1  Patients who reported that their room and bath...
# 2  Patients who reported that their room and bath...
#
#                HCAHPS Answer Description Patient Survey Star Rating  \
# 0                    Summary star rating                          3
# ...

# %%
columns_of_df(df18)# 2018 data
# Out:
#    Facility ID                     Facility Name                 Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701     H_STAR_RATING
# 1  DOTHAN    AL     36301     HOUSTON    3347938701   H_CLEAN_HSP_A_P
# 2  DOTHAN    AL     36301     HOUSTON    3347938701  H_CLEAN_HSP_SN_P
#
#                                      HCAHPS Question  \
# 0                                Summary star rating
# 1  Patients who reported that their room and bath...
# 2  Patients who reported that their room and bath...
#
#                HCAHPS Answer Description Patient Survey Star Rating  \
# 0                    Summary star rating                          2
# ...

# %%
columns_of_df(df19)# 2019 data
# Out:
#    Facility ID                     Facility Name                 Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701      H_COMP_1_A_P
# 1  DOTHAN    AL     36301     HOUSTON  (334) 793-8701     H_COMP_1_SN_P
# 2  DOTHAN    AL     36301     HOUSTON  (334) 793-8701      H_COMP_1_U_P
#
#                                      HCAHPS Question  \
# 0  Patients who reported that their nurses "Alway...
# 1  Patients who reported that their nurses "Somet...
# 2  Patients who reported that their nurses "Usual...
#
#                          HCAHPS Answer Description Patient Survey Star Rating  \
# 0                Nurses "always" communicated well             Not Applicable
# ...

# %%
columns_of_df(df20)# 2020 data
# Out:
#   Facility ID                     Facility Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701      H_COMP_1_A_P
# 1  DOTHAN    AL     36301     HOUSTON  (334) 793-8701     H_COMP_1_SN_P
# 2  DOTHAN    AL     36301     HOUSTON  (334) 793-8701      H_COMP_1_U_P
#
#                                      HCAHPS Question  \
# 0  Patients who reported that their nurses "Alway...
# 1  Patients who reported that their nurses "Somet...
# 2  Patients who reported that their nurses "Usual...
#
#                          HCAHPS Answer Description Patient Survey Star Rating  \
# 0                Nurses "always" communicated well             Not Applicable
# ...

# %% [markdown]
# we have seen that all the five datasets same no. of columns with same features, whereas for 2019 and 2020 no of rows is large as compare to 2016 ,2017 2018

# %%
info(df16)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264385 entries, 0 to 264384
# Data columns (total 43 columns):
#  #   Column                                                         Non-Null Count   Dtype
# ---  ------                                                         --------------   -----
#  0   Facility ID                                                    264385 non-null  int64
#  1   Facility Name                                                  264385 non-null  object
#  2   Address                                                        264385 non-null  object
#  3   City                                                           264385 non-null  object
#  4   State                                                          264385 non-null  object
#  5   ZIP Code                                                       264385 non-null  int64
#  6   County Name                                                    263560 non-null  object
# ...

# %%
info(df19)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442401 entries, 0 to 442400
# Data columns (total 43 columns):
#  #   Column                                                         Non-Null Count   Dtype
# ---  ------                                                         --------------   -----
#  0   Facility ID                                                    442401 non-null  int64
#  1   Facility Name                                                  442401 non-null  object
#  2   Address                                                        442401 non-null  object
#  3   City                                                           442401 non-null  object
#  4   State                                                          442401 non-null  object
#  5   ZIP Code                                                       442401 non-null  int64
#  6   County Name                                                    442401 non-null  object
# ...

# %%
df16_per = value_count(df16["Hospital overall rating"]) # value counts for 2016 rating data
print(df16_per["Hospital overall rating"].values)
# Out:
# [ 5940 37345 97570 51755  4510 67265]

# %%
df17_per = value_count(df17["Hospital overall rating"]) # value counts for 2017 rating data
df17_per
# Out:
#            index  Hospital overall rating
# 4              1                     5940
# 3              2                    37345
# 0              3                    97570
# 2              4                    51755
# 5              5                     4510
# 1  Not Available                    67265

# %%
df18_per  =value_count(df18["Hospital overall rating"]) # value counts for 2018 rating data
df18_per
# Out:
#            index  Hospital overall rating
# 4              1                     5940
# 3              2                    37345
# 0              3                    97570
# 2              4                    51755
# 5              5                     4510
# 1  Not Available                    67265

# %%
df19_per = value_count(df19["Hospital overall rating"]) # value counts for 2019 rating data
df19_per
# Out:
#            index  Hospital overall rating
# 4              1                     5940
# 3              2                    37345
# 0              3                    97570
# 2              4                    51755
# 5              5                     4510
# 1  Not Available                    67265

# %%
df20_per = value_count(df20["Hospital overall rating"]) # value counts for 2020 rating data
df20_per
# Out:
#            index  Hospital overall rating
# 4              1                     5940
# 3              2                    37345
# 0              3                    97570
# 2              4                    51755
# 5              5                     4510
# 1  Not Available                    67265

# %%
# we will filter out our data in which we dont want  "Not Available" values in  our target column
df16 = df16[df16["Hospital overall rating"] != "Not Available"]
df17 = df17[df17["Hospital overall rating"] != "Not Available"]
df18 = df18[df18["Hospital overall rating"] != "Not Available"]
df19 = df19[df19["Hospital overall rating"] != "Not Available"]
df20 = df20[df20["Hospital overall rating"] != "Not Available"]

# %%
# calculating and storing the % value of each rating for  
#every year to observe the trend as the data set is not same for all years that's why % is taken into consi
df20_per = df20["Hospital overall rating"].value_counts().reset_index()
                                                                     
df20_per.sort_values(by = "index")
# Out:
#   index  Hospital overall rating
# 4     1                    20925
# 2     2                    65286
# 1     3                   102858
# 0     4                   105648
# 3     5                    37851

# %%
# calculatinf % values for different rarinf fora particualr year for which will be useful in rleative comparsion

values = df16_per["Hospital overall rating"].values
total = df16["Hospital overall rating"].shape[0]
per_val16 = per_cal(values,total)

# %%
# for 2017
values = df17_per["Hospital overall rating"].values
total = df17["Hospital overall rating"].shape[0]
per_val17 = per_cal(values,total)

# %%
values = df18_per["Hospital overall rating"].values
total = df18["Hospital overall rating"].shape[0]
per_val18 = per_cal(values,total)

# %%
values = df19_per["Hospital overall rating"].values
total = df19["Hospital overall rating"].shape[0]
per_val19 = per_cal(values,total)

# %%
values = df20_per["Hospital overall rating"].values
total = df20["Hospital overall rating"].shape[0]
per_val20 = per_cal(values,total)

# %%
# comparing the % value of all rating  ---
print(["1","2","3","4","5"])
print(per_val16)
print(per_val17)
print(per_val18)
print(per_val19)
print(per_val20)
# Out:
# ['1', '2', '3', '4', '5']
# [3.013392857142857, 18.9453125, 49.497767857142854, 26.255580357142854, 2.2879464285714284, 34.12388392857143]
# [3.033707865168539, 19.073033707865168, 49.8314606741573, 26.43258426966292, 2.303370786516854, 34.353932584269664]
# [3.23265306122449, 20.323809523809526, 53.09931972789116, 28.165986394557823, 2.454421768707483, 36.606802721088435]
# [1.727175980041522, 10.85881935600179, 28.370464709200554, 15.048820344621038, 1.3113743552167112, 19.558668736951677]
# [31.767337807606268, 30.92841163310962, 19.630872483221477, 11.381431767337807, 6.291946308724833]

# %% [markdown]
# #  Patient Survey Star rating

# %%
df16["Patient Survey Star Rating"].value_counts()
# Out:
# Not Applicable    154112
# 3                  13684
# 4                  13355
# 2                   8248
# Not Available       3420
# 5                   2484
# 1                   1817
# Name: Patient Survey Star Rating, dtype: int64

# %%
df17["Patient Survey Star Rating"].value_counts()
# Out:
# Not Applicable    153080
# 4                  13834
# 3                  13679
# 2                   7709
# Not Available       3528
# 5                   2395
# 1                   1575
# Name: Patient Survey Star Rating, dtype: int64

# %%
df18["Patient Survey Star Rating"].value_counts()
# Out:
# Not Applicable    143325
# 3                  15672
# 4                   9780
# 2                   6373
# Not Available       4224
# 5                   2650
# 1                   1726
# Name: Patient Survey Star Rating, dtype: int64

# %%
df19["Patient Survey Star Rating"].value_counts()
# Out:
# Not Applicable    303236
# 3                  13465
# 4                  10403
# 2                   7336
# Not Available       4939
# 5                   2394
# 1                   2141
# Name: Patient Survey Star Rating, dtype: int64

# %%
df20["Patient Survey Star Rating"].value_counts()
# Out:
# Not Applicable    293232
# 3                  13783
# 4                   9791
# 2                   7200
# Not Available       4411
# 5                   2319
# 1                   1832
# Name: Patient Survey Star Rating, dtype: int64

# %% [markdown]
# Every dataset has a no. of values which are missing o not not available and a special category called Not applicable

# %%
# we will drop the not available rows
df16 = df16[df16["Patient Survey Star Rating"] != "Not Available"]
df17 = df17[df17["Patient Survey Star Rating"] != "Not Available"]
df18 = df18[df18["Patient Survey Star Rating"] != "Not Available"]
df19 = df19[df19["Patient Survey Star Rating"] != "Not Available"]
df20 = df20[df20["Patient Survey Star Rating"] != "Not Available"]
df16["Patient Survey Star Rating"].value_counts()
# Out:
# Not Applicable    154112
# 3                  13684
# 4                  13355
# 2                   8248
# 5                   2484
# 1                   1817
# Name: Patient Survey Star Rating, dtype: int64

# %%
# we will be computing the corrleation of star rating with three scenarios  
# 1.with data set contains 1 to 5 rating exclusive not applicable
#2. with not applicable dATA
# 3.WITH rating and data not applicable together for every year


# filtering data without Not applicable
df16_fil = df16[df16["Patient Survey Star Rating"] != "Not Applicable"]
df17_fil = df17[df17["Patient Survey Star Rating"] != "Not Applicable"]
df18_fil = df18[df18["Patient Survey Star Rating"] != "Not Applicable"]
df19_fil = df19[df19["Patient Survey Star Rating"] != "Not Applicable"]
df20_fil = df20[df20["Patient Survey Star Rating"] != "Not Applicable"]

# %%
# filtering the data set only for patirnt survey rating and hopital rating
df16_fill = df16_fil[["Patient Survey Star Rating","Hospital overall rating"]]
df17_fill = df17_fil[["Patient Survey Star Rating","Hospital overall rating"]]
df18_fill = df18_fil[["Patient Survey Star Rating","Hospital overall rating"]]
df19_fill = df19_fil[["Patient Survey Star Rating","Hospital overall rating"]]
df20_fill = df20_fil[["Patient Survey Star Rating","Hospital overall rating"]]

# %%
# converting the data type of both the columns to integer
#2016
df16_fill["Patient Survey Star Rating"] = pd.to_numeric(df16_fill["Patient Survey Star Rating"])
df16_fill["Hospital overall rating"] = pd.to_numeric(df16_fill["Hospital overall rating"])
#2017
df17_fill["Patient Survey Star Rating"] = pd.to_numeric(df17_fill["Patient Survey Star Rating"])
df17_fill["Hospital overall rating"] = pd.to_numeric(df17_fill["Hospital overall rating"])
#2018
df18_fill["Patient Survey Star Rating"] = pd.to_numeric(df18_fill["Patient Survey Star Rating"])
df18_fill["Hospital overall rating"] = pd.to_numeric(df18_fill["Hospital overall rating"])
#2019
df19_fill["Patient Survey Star Rating"] = pd.to_numeric(df19_fill["Patient Survey Star Rating"])
df19_fill["Hospital overall rating"] = pd.to_numeric(df19_fill["Hospital overall rating"])
#2020
df20_fill["Patient Survey Star Rating"] = pd.to_numeric(df20_fill["Patient Survey Star Rating"])
df20_fill["Hospital overall rating"] = pd.to_numeric(df20_fill["Hospital overall rating"])
# Out:
# <ipython-input-38-85b48284e1cc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16_fill["Patient Survey Star Rating"] = pd.to_numeric(df16_fill["Patient Survey Star Rating"])
# <ipython-input-38-85b48284e1cc>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16_fill["Hospital overall rating"] = pd.to_numeric(df16_fill["Hospital overall rating"])
# <ipython-input-38-85b48284e1cc>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# now computing the correlation for each year
print("For 2016")
df16_fill.corr()
# Out:
# For 2016
#                             Patient Survey Star Rating  \
# Patient Survey Star Rating                    1.000000
# Hospital overall rating                       0.512364
#
#                             Hospital overall rating
# Patient Survey Star Rating                 0.512364
# Hospital overall rating                    1.000000

# %%
sns.regplot(x = "Patient Survey Star Rating",y = "Hospital overall rating",data  = df16_fill)
plt.ylim(0,)
# Out:
# (0.0, 5.2)

# %%
print("For 2017")
df17_fill.corr()
# Out:
# For 2017
#                             Patient Survey Star Rating  \
# Patient Survey Star Rating                    1.000000
# Hospital overall rating                       0.477585
#
#                             Hospital overall rating
# Patient Survey Star Rating                 0.477585
# Hospital overall rating                    1.000000

# %%
sns.regplot(x = "Patient Survey Star Rating",y = "Hospital overall rating",data  = df17_fill)
plt.ylim(0,)
# Out:
# (0.0, 5.2)

# %%
print("For 2018")
df18_fill.corr()
# Out:
# For 2018
#                             Patient Survey Star Rating  \
# Patient Survey Star Rating                    1.000000
# Hospital overall rating                       0.470618
#
#                             Hospital overall rating
# Patient Survey Star Rating                 0.470618
# Hospital overall rating                    1.000000

# %%
sns.regplot(x = "Patient Survey Star Rating",y = "Hospital overall rating",data  = df18_fill)
plt.ylim(0,)
# Out:
# (0.0, 5.2)

# %%
print("For 2019")
df19_fill.corr()
# Out:
# For 2019
#                             Patient Survey Star Rating  \
# Patient Survey Star Rating                    1.000000
# Hospital overall rating                       0.483894
#
#                             Hospital overall rating
# Patient Survey Star Rating                 0.483894
# Hospital overall rating                    1.000000

# %%
sns.regplot(x = "Patient Survey Star Rating",y = "Hospital overall rating",data  = df19_fill)
plt.ylim(0,)
# Out:
# (0.0, 5.2)

# %%
print("For 2020")
df20_fill.corr()
# Out:
# For 2020
#                             Patient Survey Star Rating  \
# Patient Survey Star Rating                    1.000000
# Hospital overall rating                       0.484839
#
#                             Hospital overall rating
# Patient Survey Star Rating                 0.484839
# Hospital overall rating                    1.000000

# %%
# pending stillll------------------------------

# %%
import seaborn as sns

# %%
sns.regplot(x = "Patient Survey Star Rating",y = "Hospital overall rating",data  = df20_fill)
plt.ylim(0,)
# Out:
# (0.0, 5.2)

# %% [markdown]
# #  summary

# %% [markdown]
# we have seen that all the five year a very similar correlation coffecient which shows a point statistic value of relationship with the highestin 2016

# %%
# now we will compute the correlation cofficient with not applicable vlaue
df16.value_counts()
# Out:
# Series([], dtype: int64)

# %%
df16["Patient Survey Star Rating"].value_counts()
# Out:
# Not Applicable    154112
# 3                  13684
# 4                  13355
# 2                   8248
# 5                   2484
# 1                   1817
# Name: Patient Survey Star Rating, dtype: int64

# %%
# converting the "Not applicable with 0"
df16["Patient Survey Star Rating"] = df16["Patient Survey Star Rating"].replace("Not Applicable", 0)
df17["Patient Survey Star Rating"] = df17["Patient Survey Star Rating"].replace("Not Applicable", 0)
df18["Patient Survey Star Rating"] = df18["Patient Survey Star Rating"].replace("Not Applicable", 0)
df19["Patient Survey Star Rating"] = df19["Patient Survey Star Rating"].replace("Not Applicable", 0)
df20["Patient Survey Star Rating"] = df20["Patient Survey Star Rating"].replace("Not Applicable", 0)

# %%
# filtering the data
df16_a = df16[["Patient Survey Star Rating","Hospital overall rating"]]
df17_a = df17[["Patient Survey Star Rating","Hospital overall rating"]]
df18_a = df18[["Patient Survey Star Rating","Hospital overall rating"]]
df19_a = df19[["Patient Survey Star Rating","Hospital overall rating"]]
df20_a = df20[["Patient Survey Star Rating","Hospital overall rating"]]

# %%
# converting the object type data to int
df16_a["Hospital overall rating"] = pd.to_numeric(df16_a["Hospital overall rating"])
df17_a["Hospital overall rating"] = pd.to_numeric(df17_a["Hospital overall rating"])
df18_a["Hospital overall rating"] = pd.to_numeric(df18_a["Hospital overall rating"])
df19_a["Hospital overall rating"] = pd.to_numeric(df19_a["Hospital overall rating"])
df20_a["Hospital overall rating"] = pd.to_numeric(df20_a["Hospital overall rating"])
# Out:
# <ipython-input-57-c74b76da9b9d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16_a["Hospital overall rating"] = pd.to_numeric(df16_a["Hospital overall rating"])
# <ipython-input-57-c74b76da9b9d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df17_a["Hospital overall rating"] = pd.to_numeric(df17_a["Hospital overall rating"])
# <ipython-input-57-c74b76da9b9d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df16_a["Patient Survey Star Rating"] = pd.to_numeric(df16_a["Patient Survey Star Rating"])
df17_a["Patient Survey Star Rating"] = pd.to_numeric(df17_a["Patient Survey Star Rating"])
df18_a["Patient Survey Star Rating"] = pd.to_numeric(df18_a["Patient Survey Star Rating"])
df19_a["Patient Survey Star Rating"] = pd.to_numeric(df19_a["Patient Survey Star Rating"])
df20_a["Patient Survey Star Rating"] = pd.to_numeric(df20_a["Patient Survey Star Rating"])
# Out:
# <ipython-input-58-fbc4cc7e3a22>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16_a["Patient Survey Star Rating"] = pd.to_numeric(df16_a["Patient Survey Star Rating"])
# <ipython-input-58-fbc4cc7e3a22>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df17_a["Patient Survey Star Rating"] = pd.to_numeric(df17_a["Patient Survey Star Rating"])
# <ipython-input-58-fbc4cc7e3a22>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df16_a.corr()
# Out:
#                             Patient Survey Star Rating  \
# Patient Survey Star Rating                      1.0000
# Hospital overall rating                         0.0779
#
#                             Hospital overall rating
# Patient Survey Star Rating                   0.0779
# Hospital overall rating                      1.0000

# %%
df17_a.corr()
# Out:
#                             Patient Survey Star Rating  \
# Patient Survey Star Rating                     1.00000
# Hospital overall rating                        0.06996
#
#                             Hospital overall rating
# Patient Survey Star Rating                  0.06996
# Hospital overall rating                     1.00000

# %%
df18_a.corr()
# Out:
#                             Patient Survey Star Rating  \
# Patient Survey Star Rating                    1.000000
# Hospital overall rating                       0.066703
#
#                             Hospital overall rating
# Patient Survey Star Rating                 0.066703
# Hospital overall rating                    1.000000

# %% [markdown]
# # summary

# %% [markdown]
# we have seen that when we take account of all data including Not applicable hospitals as well the rated values the value of coeeficent lies between 0 to 0.1 which signify very weak correlation

# %%
# checking the hospital rating for not applicable hospitals
df16_ap = df16_a[df16["Patient Survey Star Rating"] == 0]
df17_ap = df17_a[df17["Patient Survey Star Rating"] == 0]
df18_ap = df18_a[df18["Patient Survey Star Rating"] == 0]
df19_ap = df19_a[df19["Patient Survey Star Rating"] == 0]
df20_ap = df20_a[df20["Patient Survey Star Rating"] == 0]

# %%
df16_ap
# Out:
#         Patient Survey Star Rating  Hospital overall rating
# 1                                0                        3
# 2                                0                        3
# 3                                0                        3
# 4                                0                        3
# 6                                0                        3
# ...                            ...                      ...
# 263828                           0                        3
# 263830                           0                        3
# 263831                           0                        3
# 263832                           0                        3
# 263833                           0                        3
#
# [154112 rows x 2 columns]

# %%
grp16 = df16_a.groupby("Patient Survey Star Rating")["Hospital overall rating"].value_counts()

# %%
grp16
# Out:
# Patient Survey Star Rating  Hospital overall rating
# 0                           3                          76282
#                             4                          40463
#                             2                          29197
#                             1                           4644
#                             5                           3526
# 1                           2                            916
#                             3                            506
#                             1                            341
#                             4                             53
#                             5                              1
# 2                           3                           3480
#                             2                           3365
#                             4                            693
#                             1                            686
#                             5                             24
# ...

# %% [markdown]
# # Regression Analysis

# %%
df16_r= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2016.csv")
df17_r= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2017.csv")
df18_r= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2018.csv")
df19_r= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2019.csv")
df20_r= pd.read_csv("E:\Data sets\\cms_hospital_patient_satisfaction_2020.csv")

# %%
from sklearn.metrics import r2_score

# %%
r2_16 = r2_score(df16_a["Patient Survey Star Rating"],df16_a["Hospital overall rating"])
r2_16
# Out:
# -3.4677025733062328

# %%
r2_17 = r2_score(df17_a["Patient Survey Star Rating"],df17_a["Hospital overall rating"])
r2_17
# Out:
# -3.4165295200402275

# %%
# r2 score only with ratings
r2_16_r = r2_score(df16_fill["Patient Survey Star Rating"],df16_fill["Hospital overall rating"])
r2_16_r
# Out:
# 0.1328964797071347

# %%
r2_17_r = r2_score(df17_fill["Patient Survey Star Rating"],df17_fill["Hospital overall rating"])
r2_17_r
# Out:
# 0.049367845013008727

# %%
r2_18_r = r2_score(df18_fill["Patient Survey Star Rating"],df18_fill["Hospital overall rating"])
r2_18_r
# Out:
# -0.24617808176531564

# %%
r2_19_r = r2_score(df19_fill["Patient Survey Star Rating"],df19_fill["Hospital overall rating"])
r2_19_r
# Out:
# -0.1410742540244081

# %%
r2_20_r = r2_score(df20_fill["Patient Survey Star Rating"],df20_fill["Hospital overall rating"])
r2_20_r
# Out:
# -0.21518699678609132

# %%
# building a regression model and checking the features weights
df16_r.head(30)
# Out:
#     Facility ID                     Facility Name                 Address  \
# 0         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 5         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 6         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 7         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 8         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 9         10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 10        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 11        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...

# %%
# in this data we will not consider the hcahcps questions 
# summary star rating is the average of all the ohter quesions summary rating hence, from this we can derve that we can drop the not applicable
# bcozr those question score is smmarised in star rating  
# 2.we can drop thhe not available data in hospital overall rating 
# we can also drop the  footnotes columns

# %%
df16_r.columns
# Out:
# Index(['Facility ID', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'HCAHPS Measure ID', 'HCAHPS Question',
#        'HCAHPS Answer Description', 'Patient Survey Star Rating',
#        'Patient Survey Star Rating Footnote', 'HCAHPS Answer Percent',
#        'HCAHPS Answer Percent Footnote', 'HCAHPS Linear Mean Value',
#        'Number of Completed Surveys', 'Number of Completed Surveys Footnote',
#        'Survey Response Rate Percent', 'Survey Response Rate Percent Footnote',
#        'Start Date', 'End Date', 'Year', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services',
#        'Meets criteria for promoting interoperability of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
# ...

# %%
def drop_columns(df):
    df = df.drop(columns =['Facility ID',  'ZIP Code',
        'Phone Number', 'HCAHPS Question',
       'HCAHPS Answer Description', 
       'Patient Survey Star Rating Footnote', 
       'HCAHPS Answer Percent Footnote', 'HCAHPS Linear Mean Value',
        'Number of Completed Surveys Footnote',
        'Survey Response Rate Percent Footnote',
       'Start Date', 'End Date', 'Year',  'Hospital overall rating footnote',
       'Mortality national comparison footnote',
       'Safety of care national comparison footnote',
       'Readmission national comparison footnote',
       'Patient experience national comparison footnote',
       'Effectiveness of care national comparison footnote',
       'Timeliness of care national comparison footnote',
       'Efficient use of medical imaging national comparison footnote'])
    return df
def drop_values(df):
    df = df[df["Hospital overall rating"] != "Not Available"]
    df = df[df["Patient Survey Star Rating"]!= "Not Applicable"]
    df = df[df["Patient Survey Star Rating"]!= "Not Available"]
    return  df
def replacing_categorical(df):
    df["Emergency Services"] =  df["Emergency Services"].replace({"Yes":1,"No":0})
    return df

# %%
df16_rg = drop_columns(df16_r)
df17_rg = drop_columns(df17_r)
df18_rg = drop_columns(df18_r)
df19_rg = drop_columns(df19_r)
df20_rg = drop_columns(df20_r)
df16_rg["Hospital overall rating"].value_counts()
# Out:
# 3                97570
# Not Available    67265
# 4                51755
# 2                37345
# 1                 5940
# 5                 4510
# Name: Hospital overall rating, dtype: int64

# %%
# droping the "Not Applicable values" and not availab
df16_rg = drop_values(df16_rg)
df16_rg
# Out:
#                            Facility Name                 Address  \
# 0       SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 5       SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 9       SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 14      SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 19      SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...                                  ...                     ...
# 263813          RESOLUTE HEALTH HOSPITAL     555 CREEKSIDE XING,
# 263819          RESOLUTE HEALTH HOSPITAL     555 CREEKSIDE XING,
# 263824          RESOLUTE HEALTH HOSPITAL     555 CREEKSIDE XING,
# 263829          RESOLUTE HEALTH HOSPITAL     555 CREEKSIDE XING,
# 263834          RESOLUTE HEALTH HOSPITAL     555 CREEKSIDE XING,
#
#                  City State County Name         HCAHPS Measure ID  \
# 0              DOTHAN    AL     HOUSTON             H_STAR_RATING
# ...

# %%
# Out:
# 321     120
# 628     108
# 358     108
# 187     108
# 355     108
#        ...
# 769      12
# 4870     12
# 155      12
# 2746     12
# 1509     12
# Name: Number of Completed Surveys, Length: 1529, dtype: int64

# %%
df16_rg = replacing_categorical(df16_rg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-e0ea5bca38fd> in <module>
# ----> 1 df16_rg = replacing_categorical(df16_rg)
#
# <ipython-input-125-d8b39010d6d1> in replacing_categorical(df)
#      22     return  df
#      23 def replacing_categorical(df):
# ---> 24     df["Emergency Services"] =  df["Emergency Services"].replace({"Yes":1,"No":0})
#      25     return df
#      26
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df16_rg["Emergency Services"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-8dd878f3b950> in <module>
# ----> 1 df16_rg["Emergency Services"]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-f4f89a4e7616> in <module>
# ----> 1 df16_rg.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
